# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("smoking_driking_dataset_Ver01.csv")
df.head()
# Out:
#     sex  age  height  weight  waistline  sight_left  sight_right  hear_left  \
# 0  Male   35     170      75       90.0         1.0          1.0        1.0
# 1  Male   30     180      80       89.0         0.9          1.2        1.0
# 2  Male   40     165      75       91.0         1.2          1.5        1.0
# 3  Male   50     175      80       91.0         1.5          1.2        1.0
# 4  Male   50     165      60       80.0         1.0          1.2        1.0
#
#    hear_right    SBP  ...  LDL_chole  triglyceride  hemoglobin  urine_protein  \
# 0         1.0  120.0  ...      126.0          92.0        17.1            1.0
# 1         1.0  130.0  ...      148.0         121.0        15.8            1.0
# 2         1.0  120.0  ...       74.0         104.0        15.8            1.0
# 3         1.0  145.0  ...      104.0         106.0        17.6            1.0
# 4         1.0  138.0  ...      117.0         104.0        13.8            1.0
#
# ...

# %%
df.describe()
# Out:
#                  age         height         weight      waistline  \
# count  991346.000000  991346.000000  991346.000000  991346.000000
# mean       47.614491     162.240625      63.284050      81.233358
# std        14.181339       9.282957      12.514241      11.850323
# min        20.000000     130.000000      25.000000       8.000000
# 25%        35.000000     155.000000      55.000000      74.100000
# 50%        45.000000     160.000000      60.000000      81.000000
# 75%        60.000000     170.000000      70.000000      87.800000
# max        85.000000     190.000000     140.000000     999.000000
#
#           sight_left    sight_right      hear_left     hear_right  \
# count  991346.000000  991346.000000  991346.000000  991346.000000
# mean        0.980834       0.978429       1.031495       1.030476
# std         0.605949       0.604774       0.174650       0.171892
# min         0.100000       0.100000       1.000000       1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 991346 entries, 0 to 991345
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   sex               991346 non-null  object
#  1   age               991346 non-null  int64
#  2   height            991346 non-null  int64
#  3   weight            991346 non-null  int64
#  4   waistline         991346 non-null  float64
#  5   sight_left        991346 non-null  float64
#  6   sight_right       991346 non-null  float64
#  7   hear_left         991346 non-null  float64
#  8   hear_right        991346 non-null  float64
#  9   SBP               991346 non-null  float64
#  10  DBP               991346 non-null  float64
#  11  BLDS              991346 non-null  float64
#  12  tot_chole         991346 non-null  float64
#  13  HDL_chole         991346 non-null  float64
#  14  LDL_chole         991346 non-null  float64
# ...

# %%
df_male = df[df["sex"]=="Male"]

print(len(df_male))
df_male.head()
# Out:
# 526415
#     sex  age  height  weight  waistline  sight_left  sight_right  hear_left  \
# 0  Male   35     170      75       90.0         1.0          1.0        1.0
# 1  Male   30     180      80       89.0         0.9          1.2        1.0
# 2  Male   40     165      75       91.0         1.2          1.5        1.0
# 3  Male   50     175      80       91.0         1.5          1.2        1.0
# 4  Male   50     165      60       80.0         1.0          1.2        1.0
#
#    hear_right    SBP  ...  LDL_chole  triglyceride  hemoglobin  urine_protein  \
# 0         1.0  120.0  ...      126.0          92.0        17.1            1.0
# 1         1.0  130.0  ...      148.0         121.0        15.8            1.0
# 2         1.0  120.0  ...       74.0         104.0        15.8            1.0
# 3         1.0  145.0  ...      104.0         106.0        17.6            1.0
# 4         1.0  138.0  ...      117.0         104.0        13.8            1.0
#
# ...

# %%
df_female = df[df["sex"]=="Female"]

print(len(df_female))
df_female.head()
# Out:
# 464931
#        sex  age  height  weight  waistline  sight_left  sight_right  \
# 6   Female   45     150      55       69.0         0.5          0.4
# 12  Female   55     150      55       72.3         1.2          0.9
# 14  Female   30     160      50       76.0         0.9          1.0
# 16  Female   25     160      65       73.0         1.2          0.9
# 20  Female   35     170      50       67.0         1.0          0.8
#
#     hear_left  hear_right    SBP  ...  LDL_chole  triglyceride  hemoglobin  \
# 6         1.0         1.0  101.0  ...      115.0          75.0        12.3
# 12        1.0         1.0  130.0  ...       89.0         214.0        13.1
# 14        1.0         1.0  129.0  ...      108.0         219.0        14.5
# 16        1.0         1.0  126.0  ...       82.0          60.0        12.3
# 20        1.0         1.0  111.0  ...       98.0          46.0        12.1
#
#     urine_protein  serum_creatinine  SGOT_AST  SGOT_ALT  gamma_GTP  \
# ...

# %%
df_male.describe()
# Out:
#                  age         height         weight      waistline  \
# count  526415.000000  526415.000000  526415.000000  526415.000000
# mean       46.505314     168.546119      70.125348      85.072493
# std        13.866032       6.536330      11.206268       8.204081
# min        20.000000     140.000000      40.000000      32.000000
# 25%        35.000000     165.000000      65.000000      80.000000
# 50%        45.000000     170.000000      70.000000      85.000000
# 75%        55.000000     175.000000      75.000000      90.000000
# max        85.000000     190.000000     140.000000     145.000000
#
#           sight_left    sight_right      hear_left     hear_right  \
# count  526415.000000  526415.000000  526415.000000  526415.000000
# mean        1.037220       1.036130       1.031975       1.030354
# std         0.616981       0.614377       0.175933       0.171561
# min         0.100000       0.100000       1.000000       1.000000
# ...

# %%
df_female.describe()
# Out:
#                  age         height         weight      waistline  \
# count  464931.000000  464931.000000  464931.000000  464931.000000
# mean       48.870349     155.101273      55.538037      76.886523
# std        14.427532       6.275462       8.873644      13.698197
# min        20.000000     130.000000      25.000000       8.000000
# 25%        40.000000     150.000000      50.000000      70.000000
# 50%        50.000000     155.000000      55.000000      76.000000
# 75%        60.000000     160.000000      60.000000      83.000000
# max        85.000000     175.000000     120.000000     999.000000
#
#           sight_left    sight_right      hear_left     hear_right  \
# count  464931.000000  464931.000000  464931.000000  464931.000000
# mean        0.916992       0.913098       1.030951       1.030613
# std         0.586705       0.586907       0.173185       0.172267
# min         0.100000       0.100000       1.000000       1.000000
# ...

# %%
df.describe()
# Out:
#                  age         height         weight      waistline  \
# count  991346.000000  991346.000000  991346.000000  991346.000000
# mean       47.614491     162.240625      63.284050      81.233358
# std        14.181339       9.282957      12.514241      11.850323
# min        20.000000     130.000000      25.000000       8.000000
# 25%        35.000000     155.000000      55.000000      74.100000
# 50%        45.000000     160.000000      60.000000      81.000000
# 75%        60.000000     170.000000      70.000000      87.800000
# max        85.000000     190.000000     140.000000     999.000000
#
#           sight_left    sight_right      hear_left     hear_right  \
# count  991346.000000  991346.000000  991346.000000  991346.000000
# mean        0.980834       0.978429       1.031495       1.030476
# std         0.605949       0.604774       0.174650       0.171892
# min         0.100000       0.100000       1.000000       1.000000
# ...

# %%
df_male.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 526415 entries, 0 to 991345
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   sex               526415 non-null  object
#  1   age               526415 non-null  int64
#  2   height            526415 non-null  int64
#  3   weight            526415 non-null  int64
#  4   waistline         526415 non-null  float64
#  5   sight_left        526415 non-null  float64
#  6   sight_right       526415 non-null  float64
#  7   hear_left         526415 non-null  float64
#  8   hear_right        526415 non-null  float64
#  9   SBP               526415 non-null  float64
#  10  DBP               526415 non-null  float64
#  11  BLDS              526415 non-null  float64
#  12  tot_chole         526415 non-null  float64
#  13  HDL_chole         526415 non-null  float64
#  14  LDL_chole         526415 non-null  float64
# ...

# %%
df_female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 464931 entries, 6 to 991343
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   sex               464931 non-null  object
#  1   age               464931 non-null  int64
#  2   height            464931 non-null  int64
#  3   weight            464931 non-null  int64
#  4   waistline         464931 non-null  float64
#  5   sight_left        464931 non-null  float64
#  6   sight_right       464931 non-null  float64
#  7   hear_left         464931 non-null  float64
#  8   hear_right        464931 non-null  float64
#  9   SBP               464931 non-null  float64
#  10  DBP               464931 non-null  float64
#  11  BLDS              464931 non-null  float64
#  12  tot_chole         464931 non-null  float64
#  13  HDL_chole         464931 non-null  float64
#  14  LDL_chole         464931 non-null  float64
# ...

# %%
correlation_matrix = df.corr()

# Korelasyon matrisini renkli bir şekilde görselleştirme
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".1f", cmap='coolwarm', linewidths=0.5)
plt.title('Korelasyon Matrisi')
plt.show()

# %%
correlation_matrix = df_male.corr()

# Korelasyon matrisini renkli bir şekilde görselleştirme
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".1f", cmap='coolwarm', linewidths=0.5)
plt.title('Korelasyon Matrisi')
plt.show()
